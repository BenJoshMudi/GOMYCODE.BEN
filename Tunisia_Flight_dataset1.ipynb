# %% [markdown]
# <a href="https://colab.research.google.com/github/BenJoshMudi/GOMYCODE.BEN/blob/main/Tunisia_Flight_dataset1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
Tun_df = pd.read_csv("Tunisair_flights_dataset.csv")
Tun_df.head()
# Out:
#   Filght_date Flight_ID Departure point Arrival point  \
# 0  2016-01-03  TU 0712              CMN           TUN
# 1  2016-01-13  TU 0757              MXP           TUN
# 2  2016-01-16  TU 0214              TUN           IST
# 3  2016-01-17  TU 0480              DJE           NTE
# 4  2016-01-17  TU 0338              TUN           ALG
#
#   Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0      2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1      2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# 2      2016-01-16 04:10:00    2016-01-16 06.45.00    ATA     TU 32AIMN
# 3      2016-01-17 14:10:00    2016-01-17 17.00.00    ATA     TU 736IOK
# 4      2016-01-17 14:30:00    2016-01-17 15.50.00    ATA     TU 320IMU
#
#    Arrival delay
# 0          260.0
# 1           20.0
# 2            0.0
# 3            0.0
# 4           22.0

# %%
Tun_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60446 entries, 0 to 60445
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Filght_date               60446 non-null  object
#  1   Flight_ID                 60446 non-null  object
#  2   Departure point           60446 non-null  object
#  3   Arrival point             60446 non-null  object
#  4   Scheduled_departure_time  60446 non-null  object
#  5   Scheduled_arrival_time    60446 non-null  object
#  6   STATUS                    60445 non-null  object
#  7   Aircraft_code             60445 non-null  object
#  8   Arrival delay             60445 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 4.2+ MB

# %%
Tun_df.describe()
# Out:
#        Arrival delay
# count   60445.000000
# mean       45.284854
# std       109.577278
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        40.000000
# max      3451.000000

# %%
Tun_df.isnull().sum()
# Out:
# Filght_date                 0
# Flight_ID                   0
# Departure point             0
# Arrival point               0
# Scheduled_departure_time    0
# Scheduled_arrival_time      0
# STATUS                      1
# Aircraft_code               1
# Arrival delay               1
# dtype: int64

# %%
Tun_df.describe()
# Out:
#        Arrival delay
# count   60445.000000
# mean       45.284854
# std       109.577278
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        40.000000
# max      3451.000000

# %%
profile = ProfileReport(Tun_df, title = "Tunisia flights")
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-23 13:38:09.935321&quot;&gt;&lt;title&gt;Tunisia flights&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
"""Report:
2. Look for missing values in the dataset. You can use the report generated by ydata-profiling to identify missing values.

ANSWER: from the overview section, the missing value is nil, therefore there is no missing values in the dataset

3. Look for correlations between different columns in the dataset. You can use the report generated by ydata-profiling to identify correlations between different columns.

ANSWER: There is no correlation between the arrival and status from the heatmap provided.

4.To check for outliers between Q1 and P50 (median): Calculate the difference: Gap=P50−Q1.
The P50 is 14 while the Q1 is 0. This may indicate the presence of outliers.

In Summary, There is no correlation between the two variables in the dataset,
I did not encountered any issues when exploring my dataset. The descriptive statistics of the dataset
was easily calculated using pandas describe() function. for effective use of the dataset,
the info method was used to observe the datatype involved in the dataset.
while the isnull() function was used to check for missing values and any feature with missing values
should be corrected using the neccessary technique as this may affect the integrity of our report.
In our dataset, there is no missing values
The ydata-profiling was used to give a quick anaysis of the dataset.
it gives many information about the dataset. It was used to check for missing and duplicate values and
also to see the relationship and pattern between variables in the dataset.
"""
